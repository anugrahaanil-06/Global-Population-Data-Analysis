# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# %%
from google.colab import files
files.upload ()
# Out:
#      <input type="file" id="files-6260dac3-26d5-4c6d-ae8e-d5c2147e2807" name="files[]" multiple disabled
#         style="border:none" />
#      <output id="result-6260dac3-26d5-4c6d-ae8e-d5c2147e2807">
#       Upload widget is only available when the cell has been executed in the
#       current browser session. Please rerun this cell to enable.
#       </output>
#       <script>// Copyright 2017 Google LLC
# //
# // Licensed under the Apache License, Version 2.0 (the "License");
# // you may not use this file except in compliance with the License.
# // You may obtain a copy of the License at
# //
# //      http://www.apache.org/licenses/LICENSE-2.0
# //
# // Unless required by applicable law or agreed to in writing, software
# // distributed under the License is distributed on an "AS IS" BASIS,
# // WITHOUT WARRANTIES OR CONDITIONS OF ANY KIND, either express or implied.
# // See the License for the specific language governing permissions and
# // limitations under the License.
#
# ...

# %%
df=pd.read_csv("global_population_stats_2024.csv")
df
# Out:
#          Country  Population Aged 0 to 14 (%)  \
# 0    Afghanistan                         42.9
# 1        Albania                         16.8
# 2        Algeria                         30.3
# 3        Andorra                         11.9
# 4         Angola                         44.4
# ..           ...                          ...
# 187    Venezuela                         25.5
# 188      Vietnam                         23.2
# 189        Yemen                         41.1
# 190       Zambia                         41.5
# 191     Zimbabwe                         40.9
#
#      Population Aged 60 and Over (%)  Population density  \
# 0                                3.9                65.7
# 1                               23.5               101.9
# 2                               10.0                19.7
# 3                               23.2               174.3
# 4                                4.6                30.4
# ..                               ...                 ...
# ...

# %%
df.head()
# Out:
#        Country  Population Aged 0 to 14 (%)  Population Aged 60 and Over (%)  \
# 0  Afghanistan                         42.9                              3.9
# 1      Albania                         16.8                             23.5
# 2      Algeria                         30.3                             10.0
# 3      Andorra                         11.9                             23.2
# 4       Angola                         44.4                              4.6
#
#    Population density  Population(in millions)  \
# 0                65.7                    42.65
# 1               101.9                     2.79
# 2                19.7                    46.81
# 3               174.3                     0.08
# 4                30.4                    37.89
#
#    Female Population(in millions)  Male Population(in millions)  \
# 0                           21.12                         21.53
# 1                            1.41                          1.38
# ...

# %%
df.tail()
# Out:
#        Country  Population Aged 0 to 14 (%)  Population Aged 60 and Over (%)  \
# 187  Venezuela                         25.5                             14.3
# 188    Vietnam                         23.2                             13.9
# 189      Yemen                         41.1                              4.0
# 190     Zambia                         41.5                              3.3
# 191   Zimbabwe                         40.9                              5.0
#
#      Population density  Population(in millions)  \
# 187                31.0                    28.41
# 188               322.2                   100.99
# 189                76.9                    40.58
# 190                28.7                    21.32
# 191                43.0                    16.63
#
#      Female Population(in millions)  Male Population(in millions)  \
# 187                           14.37                         14.03
# 188                           51.53                         49.46
# ...

# %%
df.shape
# Out:
# (192, 8)

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 192 entries, 0 to 191
# Data columns (total 8 columns):
#  #   Column                             Non-Null Count  Dtype
# ---  ------                             --------------  -----
#  0   Country                            192 non-null    object
#  1   Population Aged 0 to 14 (%)        192 non-null    float64
#  2   Population Aged 60 and Over (%)    192 non-null    float64
#  3   Population density                 192 non-null    float64
#  4   Population(in millions)            192 non-null    float64
#  5   Female Population(in millions)     192 non-null    float64
#  6   Male Population(in millions)       192 non-null    float64
#  7   Sex ratio (males per 100 females)  192 non-null    float64
# dtypes: float64(7), object(1)
# memory usage: 12.1+ KB

# %%
df.describe()
# Out:
#        Population Aged 0 to 14 (%)  Population Aged 60 and Over (%)  \
# count                   192.000000                       192.000000
# mean                     26.308333                        14.167188
# std                      10.328998                         9.106158
# min                      10.600000                         3.300000
# 25%                      17.000000                         6.100000
# 50%                      24.650000                        11.250000
# 75%                      36.350000                        22.250000
# max                      49.000000                        43.500000
#
#        Population density  Population(in millions)  \
# count          192.000000               192.000000
# mean           348.131771                42.267812
# std           1969.940293               151.787795
# min              2.200000                 0.010000
# 25%             36.550000                 2.180000
# ...

# %%
df.columns
# Out:
# Index(['Country', 'Population Aged 0 to 14 (%)',
#        'Population Aged 60 and Over (%)', 'Population density',
#        'Population(in millions)', 'Female Population(in millions)',
#        'Male Population(in millions)', 'Sex ratio (males per 100 females)'],
#       dtype='object')

# %%
df.isnull().sum()
# Out:
# Country                              0
# Population Aged 0 to 14 (%)          0
# Population Aged 60 and Over (%)      0
# Population density                   0
# Population(in millions)              0
# Female Population(in millions)       0
# Male Population(in millions)         0
# Sex ratio (males per 100 females)    0
# dtype: int64

# %%
print(df.corr(numeric_only=True), "\n")
# Out:
#                                    Population Aged 0 to 14 (%)  \
# Population Aged 0 to 14 (%)                           1.000000
# Population Aged 60 and Over (%)                      -0.856342
# Population density                                   -0.137762
# Population(in millions)                              -0.042150
# Female Population(in millions)                       -0.042948
# Male Population(in millions)                         -0.041374
# Sex ratio (males per 100 females)                    -0.063384
#
#                                    Population Aged 60 and Over (%)  \
# Population Aged 0 to 14 (%)                              -0.856342
# Population Aged 60 and Over (%)                           1.000000
# Population density                                        0.236849
# Population(in millions)                                   0.009179
# Female Population(in millions)                            0.011375
# ...

# %%
plt.figure(figsize=(8,5))
sns.heatmap(df.corr(numeric_only=True), annot=True,cmap='coolwarm', fmt=".2f")
plt.title("Correlation Heatmap")
plt.show()

# %%
df.hist(figsize=(10,8), bins=10, edgecolor='black')
plt.suptitle("Distribution of Numerical Features", y=1.02)
plt.show()

# %%
plt.figure(figsize=(10,5))
df.plot(x='Country', y=['Population Aged 0 to 14 (%)', 'Population Aged 60 and Over (%)'], kind='bar')
plt.title("Age Group Comparison (0–14 vs 60+) by Country")
plt.ylabel("Percentage")
plt.xticks(rotation=45)
plt.show()

# %%
plt.figure(figsize=(8,5))
sns.barplot(x='Country', y='Population(in millions)', data=df, palette='viridis')
plt.title("Total Population by Country")
plt.ylabel("Population (millions)")
plt.show()
# Out:
# /tmp/ipython-input-1900146671.py:2: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `x` variable to `hue` and set `legend=False` for the same effect.
#
#   sns.barplot(x='Country', y='Population(in millions)', data=df, palette='viridis')

# %%
plt.figure(figsize=(8,5))
sns.barplot(x='Country', y='Population density', data=df, palette='magma')
plt.title("Population Density by Country")
plt.ylabel("People per km²")
plt.show()
# Out:
# /tmp/ipython-input-863342812.py:2: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `x` variable to `hue` and set `legend=False` for the same effect.
#
#   sns.barplot(x='Country', y='Population density', data=df, palette='magma')

# %%
plt.figure(figsize=(8,5))
sns.barplot(x='Country', y='Sex ratio (males per 100 females)', data=df, palette='cool')
plt.title("Sex Ratio by Country")
plt.ylabel("Males per 100 Females")
plt.show()
# Out:
# /tmp/ipython-input-1463463075.py:2: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `x` variable to `hue` and set `legend=False` for the same effect.
#
#   sns.barplot(x='Country', y='Sex ratio (males per 100 females)', data=df, palette='cool')

# %%
plt.figure(figsize=(10,6))
sns.boxplot(data=df.select_dtypes(include=[np.number]))
plt.title("Boxplot for Outlier Detection")
plt.show()

# %%
top_pop = df.nlargest(10, 'Population(in millions)')

plt.figure(figsize=(10,5))
sns.barplot(x='Country', y='Population(in millions)', data=top_pop, palette='viridis')
plt.title("Top 10 Countries by Total Population", fontsize=13, fontweight='bold')
plt.ylabel("Population (in millions)")
plt.xlabel("Country")
plt.xticks(rotation=45)
plt.tight_layout()
plt.show()
# Out:
# /tmp/ipython-input-1875368964.py:4: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `x` variable to `hue` and set `legend=False` for the same effect.
#
#   sns.barplot(x='Country', y='Population(in millions)', data=top_pop, palette='viridis')

# %%
plt.figure(figsize=(10,5))
top_pop.plot(
    x='Country',
    y=['Population Aged 0 to 14 (%)', 'Population Aged 60 and Over (%)'],
    kind='bar',
    color=['#1f77b4','#ff7f0e'],
    edgecolor='black'
)
plt.title("Age Group Comparison (0–14 vs 60+) - Top 10 Countries", fontsize=13, fontweight='bold')
plt.ylabel("Percentage")
plt.xticks(rotation=45)
plt.tight_layout()
plt.show()

# %%
top_density = df.nlargest(10, 'Population density')

plt.figure(figsize=(10,5))
sns.barplot(x='Country', y='Population density', data=top_density, palette='mako')
plt.title("Top 10 Countries by Population Density", fontsize=13, fontweight='bold')
plt.ylabel("People per km²")
plt.xlabel("Country")
plt.xticks(rotation=45)
plt.tight_layout()
plt.show()
# Out:
# /tmp/ipython-input-1286415630.py:4: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `x` variable to `hue` and set `legend=False` for the same effect.
#
#   sns.barplot(x='Country', y='Population density', data=top_density, palette='mako')

# %%
top_young = df.nlargest(10, 'Population Aged 0 to 14 (%)')

plt.figure(figsize=(10,5))
sns.barplot(x='Country', y='Population Aged 0 to 14 (%)', data=top_young, palette='coolwarm')
plt.title("Top 10 Countries with Youngest Populations (Age 0–14 %)", fontsize=13, fontweight='bold')
plt.ylabel("Percentage of Youth Population")
plt.xticks(rotation=45)
plt.tight_layout()
plt.show()
# Out:
# /tmp/ipython-input-2765120313.py:4: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `x` variable to `hue` and set `legend=False` for the same effect.
#
#   sns.barplot(x='Country', y='Population Aged 0 to 14 (%)', data=top_young, palette='coolwarm')

# %%
top_old = df.nlargest(10, 'Population Aged 60 and Over (%)')

plt.figure(figsize=(10,5))
sns.barplot(x='Country', y='Population Aged 60 and Over (%)', data=top_old, palette='crest')
plt.title("Top 10 Countries with Oldest Populations (Age 60+ %)", fontsize=13, fontweight='bold')
plt.ylabel("Percentage of Elderly Population")
plt.xticks(rotation=45)
plt.tight_layout()
plt.show()
# Out:
# /tmp/ipython-input-2867855506.py:4: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `x` variable to `hue` and set `legend=False` for the same effect.
#
#   sns.barplot(x='Country', y='Population Aged 60 and Over (%)', data=top_old, palette='crest')

# %%
plt.figure(figsize=(10,5))
sns.barplot(x='Country', y='Sex ratio (males per 100 females)', data=top_pop, palette='flare')
plt.title("Sex Ratio by Country — Top 10 Populated Nations", fontsize=13, fontweight='bold')
plt.ylabel("Males per 100 Females")
plt.axhline(100, color='gray', linestyle='--', linewidth=1)
plt.xticks(rotation=45)
plt.tight_layout()
plt.show()
# Out:
# /tmp/ipython-input-2173488584.py:2: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `x` variable to `hue` and set `legend=False` for the same effect.
#
#   sns.barplot(x='Country', y='Sex ratio (males per 100 females)', data=top_pop, palette='flare')

# %%
plt.figure(figsize=(8,6))
sns.heatmap(df.corr(numeric_only=True), annot=True, cmap='coolwarm', fmt=".2f")
plt.title("Correlation Heatmap — Population Variables", fontsize=13, fontweight='bold')
plt.tight_layout()
plt.show()
